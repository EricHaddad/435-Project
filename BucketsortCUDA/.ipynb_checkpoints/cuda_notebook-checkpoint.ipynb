# %% [markdown]
# # Lab 1 Analysis Example using Thicket

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("*random.cali")) # dividing it by input type for now
tk.statsframe.dataframe["time"] = 1

# %%
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     ├─ 1.000 cudaMemcpy_device_to_host
# │     └─ 1.000 cudaMemcpy_host_to_device
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# Performance data
tk.dataframe
# Out:
#                                                                nid  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021     1
#                                                    2187979912    1
#                                                    2204706642    1
#                                                    3547712491    1
#                                                    3707441980    1
# {'name': 'comm', 'type': 'function'}               140327021     3
#                                                    2187979912    3
#                                                    2204706642    3
#                                                    3547712491    3
#                                                    3707441980    3
# {'name': 'comm_large', 'type': 'function'}         140327021     4
#                                                    2187979912    4
#                                                    2204706642    4
#                                                    3547712491    4
#                                                    3707441980    4
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021     8
#                                                    2187979912    8
#                                                    2204706642    8
#                                                    3547712491    8
#                                                    3707441980    8
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021     5
#                                                    2187979912    5
#                                                    2204706642    5
#                                                    3547712491    5
#                                                    3707441980    5
# {'name': 'comp', 'type': 'function'}               140327021     6
#                                                    2187979912    6
#                                                    2204706642    6
#                                                    3547712491    6
#                                                    3707441980    6
# {'name': 'comp_large', 'type': 'function'}         140327021     7
#                                                    2187979912    7
#                                                    2204706642    7
#                                                    3547712491    7
#                                                    3707441980    7
# {'name': 'correctness_check', 'type': 'function'}  140327021     9
#                                                    2187979912    9
#                                                    2204706642    9
#                                                    3547712491    9
#                                                    3707441980    9
# {'name': 'data_init', 'type': 'function'}          140327021     2
#                                                    2187979912    2
#                                                    2204706642    2
#                                                    3547712491    2
#                                                    3707441980    2
#
#                                                                 spot.channel  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'comm', 'type': 'function'}               140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'comm_large', 'type': 'function'}         140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'comp', 'type': 'function'}               140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'comp_large', 'type': 'function'}         140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'correctness_check', 'type': 'function'}  140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
# {'name': 'data_init', 'type': 'function'}          140327021   regionprofile
#                                                    2187979912  regionprofile
#                                                    2204706642  regionprofile
#                                                    3547712491  regionprofile
#                                                    3707441980  regionprofile
#
#                                                                Min time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021        0.618255
#                                                    2187979912       0.761927
#                                                    2204706642       0.982549
#                                                    3547712491       0.634789
#                                                    3707441980       0.774595
# {'name': 'comm', 'type': 'function'}               140327021        0.001508
#                                                    2187979912       0.001446
#                                                    2204706642       0.001402
#                                                    3547712491       0.001524
#                                                    3707441980       0.001724
# {'name': 'comm_large', 'type': 'function'}         140327021        0.001447
#                                                    2187979912       0.001388
#                                                    2204706642       0.001342
#                                                    3547712491       0.001467
#                                                    3707441980       0.001640
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021        0.000425
#                                                    2187979912       0.000374
#                                                    2204706642       0.000317
#                                                    3547712491       0.000469
#                                                    3707441980       0.000363
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021        0.000978
#                                                    2187979912       0.000975
#                                                    2204706642       0.000982
#                                                    3547712491       0.000960
#                                                    3707441980       0.001202
# {'name': 'comp', 'type': 'function'}               140327021        0.249733
#                                                    2187979912       0.249065
#                                                    2204706642       0.249305
#                                                    3547712491       0.248447
#                                                    3707441980       0.253706
# {'name': 'comp_large', 'type': 'function'}         140327021        0.249693
#                                                    2187979912       0.249030
#                                                    2204706642       0.249268
#                                                    3547712491       0.248411
#                                                    3707441980       0.253634
# {'name': 'correctness_check', 'type': 'function'}  140327021        0.002971
#                                                    2187979912       0.002960
#                                                    2204706642       0.002948
#                                                    3547712491       0.004667
#                                                    3707441980       0.002981
# {'name': 'data_init', 'type': 'function'}          140327021        0.022264
#                                                    2187979912       0.021755
#                                                    2204706642       0.022713
#                                                    3547712491       0.022155
#                                                    3707441980       0.022017
#
#                                                                Max time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021        0.618255
#                                                    2187979912       0.761927
#                                                    2204706642       0.982549
#                                                    3547712491       0.634789
#                                                    3707441980       0.774595
# {'name': 'comm', 'type': 'function'}               140327021        0.001508
#                                                    2187979912       0.001446
#                                                    2204706642       0.001402
#                                                    3547712491       0.001524
#                                                    3707441980       0.001724
# {'name': 'comm_large', 'type': 'function'}         140327021        0.001447
#                                                    2187979912       0.001388
#                                                    2204706642       0.001342
#                                                    3547712491       0.001467
#                                                    3707441980       0.001640
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021        0.000425
#                                                    2187979912       0.000374
#                                                    2204706642       0.000317
#                                                    3547712491       0.000469
#                                                    3707441980       0.000363
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021        0.000978
#                                                    2187979912       0.000975
#                                                    2204706642       0.000982
#                                                    3547712491       0.000960
#                                                    3707441980       0.001202
# {'name': 'comp', 'type': 'function'}               140327021        0.249733
#                                                    2187979912       0.249065
#                                                    2204706642       0.249305
#                                                    3547712491       0.248447
#                                                    3707441980       0.253706
# {'name': 'comp_large', 'type': 'function'}         140327021        0.249693
#                                                    2187979912       0.249030
#                                                    2204706642       0.249268
#                                                    3547712491       0.248411
#                                                    3707441980       0.253634
# {'name': 'correctness_check', 'type': 'function'}  140327021        0.002971
#                                                    2187979912       0.002960
#                                                    2204706642       0.002948
#                                                    3547712491       0.004667
#                                                    3707441980       0.002981
# {'name': 'data_init', 'type': 'function'}          140327021        0.022264
#                                                    2187979912       0.021755
#                                                    2204706642       0.022713
#                                                    3547712491       0.022155
#                                                    3707441980       0.022017
#
#                                                                Avg time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021        0.618255
#                                                    2187979912       0.761927
#                                                    2204706642       0.982549
#                                                    3547712491       0.634789
#                                                    3707441980       0.774595
# {'name': 'comm', 'type': 'function'}               140327021        0.001508
#                                                    2187979912       0.001446
#                                                    2204706642       0.001402
#                                                    3547712491       0.001524
#                                                    3707441980       0.001724
# {'name': 'comm_large', 'type': 'function'}         140327021        0.001447
#                                                    2187979912       0.001388
#                                                    2204706642       0.001342
#                                                    3547712491       0.001467
#                                                    3707441980       0.001640
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021        0.000425
#                                                    2187979912       0.000374
#                                                    2204706642       0.000317
#                                                    3547712491       0.000469
#                                                    3707441980       0.000363
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021        0.000978
#                                                    2187979912       0.000975
#                                                    2204706642       0.000982
#                                                    3547712491       0.000960
#                                                    3707441980       0.001202
# {'name': 'comp', 'type': 'function'}               140327021        0.249733
#                                                    2187979912       0.249065
#                                                    2204706642       0.249305
#                                                    3547712491       0.248447
#                                                    3707441980       0.253706
# {'name': 'comp_large', 'type': 'function'}         140327021        0.249693
#                                                    2187979912       0.249030
#                                                    2204706642       0.249268
#                                                    3547712491       0.248411
#                                                    3707441980       0.253634
# {'name': 'correctness_check', 'type': 'function'}  140327021        0.002971
#                                                    2187979912       0.002960
#                                                    2204706642       0.002948
#                                                    3547712491       0.004667
#                                                    3707441980       0.002981
# {'name': 'data_init', 'type': 'function'}          140327021        0.022264
#                                                    2187979912       0.021755
#                                                    2204706642       0.022713
#                                                    3547712491       0.022155
#                                                    3707441980       0.022017
#
#                                                                Total time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021     0.618255
#                                                    2187979912    0.761927
#                                                    2204706642    0.982549
#                                                    3547712491    0.634789
#                                                    3707441980    0.774595
# {'name': 'comm', 'type': 'function'}               140327021     0.001508
#                                                    2187979912    0.001446
#                                                    2204706642    0.001402
#                                                    3547712491    0.001524
#                                                    3707441980    0.001724
# {'name': 'comm_large', 'type': 'function'}         140327021     0.001447
#                                                    2187979912    0.001388
#                                                    2204706642    0.001342
#                                                    3547712491    0.001467
#                                                    3707441980    0.001640
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021     0.000425
#                                                    2187979912    0.000374
#                                                    2204706642    0.000317
#                                                    3547712491    0.000469
#                                                    3707441980    0.000363
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021     0.000978
#                                                    2187979912    0.000975
#                                                    2204706642    0.000982
#                                                    3547712491    0.000960
#                                                    3707441980    0.001202
# {'name': 'comp', 'type': 'function'}               140327021     0.249733
#                                                    2187979912    0.249065
#                                                    2204706642    0.249305
#                                                    3547712491    0.248447
#                                                    3707441980    0.253706
# {'name': 'comp_large', 'type': 'function'}         140327021     0.249693
#                                                    2187979912    0.249030
#                                                    2204706642    0.249268
#                                                    3547712491    0.248411
#                                                    3707441980    0.253634
# {'name': 'correctness_check', 'type': 'function'}  140327021     0.002971
#                                                    2187979912    0.002960
#                                                    2204706642    0.002948
#                                                    3547712491    0.004667
#                                                    3707441980    0.002981
# {'name': 'data_init', 'type': 'function'}          140327021     0.022264
#                                                    2187979912    0.021755
#                                                    2204706642    0.022713
#                                                    3547712491    0.022155
#                                                    3707441980    0.022017
#
#                                                                Avg GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021            0.001194
#                                                    2187979912           0.001144
#                                                    2204706642           0.001090
#                                                    3547712491           0.001218
#                                                    3707441980           0.001333
# {'name': 'comm', 'type': 'function'}               140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'comm_large', 'type': 'function'}         140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021            0.000003
#                                                    2187979912           0.000003
#                                                    2204706642           0.000003
#                                                    3547712491           0.000003
#                                                    3707441980           0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021            0.000759
#                                                    2187979912           0.000761
#                                                    2204706642           0.000756
#                                                    3547712491           0.000741
#                                                    3707441980           0.000921
# {'name': 'comp', 'type': 'function'}               140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'comp_large', 'type': 'function'}         140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'correctness_check', 'type': 'function'}  140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
# {'name': 'data_init', 'type': 'function'}          140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
#
#                                                                Min GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021            0.001194
#                                                    2187979912           0.001144
#                                                    2204706642           0.001090
#                                                    3547712491           0.001218
#                                                    3707441980           0.001333
# {'name': 'comm', 'type': 'function'}               140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'comm_large', 'type': 'function'}         140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021            0.000003
#                                                    2187979912           0.000003
#                                                    2204706642           0.000003
#                                                    3547712491           0.000003
#                                                    3707441980           0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021            0.000759
#                                                    2187979912           0.000761
#                                                    2204706642           0.000756
#                                                    3547712491           0.000741
#                                                    3707441980           0.000921
# {'name': 'comp', 'type': 'function'}               140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'comp_large', 'type': 'function'}         140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'correctness_check', 'type': 'function'}  140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
# {'name': 'data_init', 'type': 'function'}          140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
#
#                                                                Max GPU time/rank  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021            0.001194
#                                                    2187979912           0.001144
#                                                    2204706642           0.001090
#                                                    3547712491           0.001218
#                                                    3707441980           0.001333
# {'name': 'comm', 'type': 'function'}               140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'comm_large', 'type': 'function'}         140327021            0.000762
#                                                    2187979912           0.000764
#                                                    2204706642           0.000759
#                                                    3547712491           0.000744
#                                                    3707441980           0.000924
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021            0.000003
#                                                    2187979912           0.000003
#                                                    2204706642           0.000003
#                                                    3547712491           0.000003
#                                                    3707441980           0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021            0.000759
#                                                    2187979912           0.000761
#                                                    2204706642           0.000756
#                                                    3547712491           0.000741
#                                                    3707441980           0.000921
# {'name': 'comp', 'type': 'function'}               140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'comp_large', 'type': 'function'}         140327021            0.000431
#                                                    2187979912           0.000380
#                                                    2204706642           0.000331
#                                                    3547712491           0.000474
#                                                    3707441980           0.000409
# {'name': 'correctness_check', 'type': 'function'}  140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
# {'name': 'data_init', 'type': 'function'}          140327021                 NaN
#                                                    2187979912                NaN
#                                                    2204706642                NaN
#                                                    3547712491                NaN
#                                                    3707441980                NaN
#
#                                                                Total GPU time  \
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021         0.001194
#                                                    2187979912        0.001144
#                                                    2204706642        0.001090
#                                                    3547712491        0.001218
#                                                    3707441980        0.001333
# {'name': 'comm', 'type': 'function'}               140327021         0.000762
#                                                    2187979912        0.000764
#                                                    2204706642        0.000759
#                                                    3547712491        0.000744
#                                                    3707441980        0.000924
# {'name': 'comm_large', 'type': 'function'}         140327021         0.000762
#                                                    2187979912        0.000764
#                                                    2204706642        0.000759
#                                                    3547712491        0.000744
#                                                    3707441980        0.000924
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021         0.000003
#                                                    2187979912        0.000003
#                                                    2204706642        0.000003
#                                                    3547712491        0.000003
#                                                    3707441980        0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021         0.000759
#                                                    2187979912        0.000761
#                                                    2204706642        0.000756
#                                                    3547712491        0.000741
#                                                    3707441980        0.000921
# {'name': 'comp', 'type': 'function'}               140327021         0.000431
#                                                    2187979912        0.000380
#                                                    2204706642        0.000331
#                                                    3547712491        0.000474
#                                                    3707441980        0.000409
# {'name': 'comp_large', 'type': 'function'}         140327021         0.000431
#                                                    2187979912        0.000380
#                                                    2204706642        0.000331
#                                                    3547712491        0.000474
#                                                    3707441980        0.000409
# {'name': 'correctness_check', 'type': 'function'}  140327021              NaN
#                                                    2187979912             NaN
#                                                    2204706642             NaN
#                                                    3547712491             NaN
#                                                    3707441980             NaN
# {'name': 'data_init', 'type': 'function'}          140327021              NaN
#                                                    2187979912             NaN
#                                                    2204706642             NaN
#                                                    3547712491             NaN
#                                                    3707441980             NaN
#
#                                                                                     name
# node                                               profile
# {'name': 'main', 'type': 'function'}               140327021                        main
#                                                    2187979912                       main
#                                                    2204706642                       main
#                                                    3547712491                       main
#                                                    3707441980                       main
# {'name': 'comm', 'type': 'function'}               140327021                        comm
#                                                    2187979912                       comm
#                                                    2204706642                       comm
#                                                    3547712491                       comm
#                                                    3707441980                       comm
# {'name': 'comm_large', 'type': 'function'}         140327021                  comm_large
#                                                    2187979912                 comm_large
#                                                    2204706642                 comm_large
#                                                    3547712491                 comm_large
#                                                    3707441980                 comm_large
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 140327021   cudaMemcpy_device_to_host
#                                                    2187979912  cudaMemcpy_device_to_host
#                                                    2204706642  cudaMemcpy_device_to_host
#                                                    3547712491  cudaMemcpy_device_to_host
#                                                    3707441980  cudaMemcpy_device_to_host
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 140327021   cudaMemcpy_host_to_device
#                                                    2187979912  cudaMemcpy_host_to_device
#                                                    2204706642  cudaMemcpy_host_to_device
#                                                    3547712491  cudaMemcpy_host_to_device
#                                                    3707441980  cudaMemcpy_host_to_device
# {'name': 'comp', 'type': 'function'}               140327021                        comp
#                                                    2187979912                       comp
#                                                    2204706642                       comp
#                                                    3547712491                       comp
#                                                    3707441980                       comp
# {'name': 'comp_large', 'type': 'function'}         140327021                  comp_large
#                                                    2187979912                 comp_large
#                                                    2204706642                 comp_large
#                                                    3547712491                 comp_large
#                                                    3707441980                 comp_large
# {'name': 'correctness_check', 'type': 'function'}  140327021           correctness_check
#                                                    2187979912          correctness_check
#                                                    2204706642          correctness_check
#                                                    3547712491          correctness_check
#                                                    3707441980          correctness_check
# {'name': 'data_init', 'type': 'function'}          140327021                   data_init
#                                                    2187979912                  data_init
#                                                    2204706642                  data_init
#                                                    3547712491                  data_init
#                                                    3707441980                  data_init

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 140327021            2.11.0-dev
# 2187979912           2.11.0-dev
# 2204706642           2.11.0-dev
# 3547712491           2.11.0-dev
# 3707441980           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 140327021   min#inclusive#sum#time.duration,max#inclusive#...
# 2187979912  min#inclusive#sum#time.duration,max#inclusive#...
# 2204706642  min#inclusive#sum#time.duration,max#inclusive#...
# 3547712491  min#inclusive#sum#time.duration,max#inclusive#...
# 3707441980  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 140327021                                             2
# 2187979912                                            2
# 2204706642                                            2
# 3547712491                                            2
# 3707441980                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 140327021   cuda.gputime,node.order  regionprofile         spot
# 2187979912  cuda.gputime,node.order  regionprofile         spot
# 2204706642  cuda.gputime,node.order  regionprofile         spot
# 3547712491  cuda.gputime,node.order  regionprofile         spot
# 3707441980  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order                 spot:output  \
# profile
# 140327021               true            true   t128-v1048576-random.cali
# 2187979912              true            true   t256-v1048576-random.cali
# 2204706642              true            true   t512-v1048576-random.cali
# 3547712491              true            true  t1024-v1048576-random.cali
# 3707441980              true            true    t64-v1048576-random.cali
#
#             launchdate                                          libraries  \
# profile
# 140327021   1700098803  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2187979912  1700098802  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2204706642  1700104042  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3547712491  1700104166  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3707441980  1700098802  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                               cmdline cluster   Algorithm  \
# profile
# 140327021    [./bucketsortCUDA, 128, 1048576, random]       g  BucketSort
# 2187979912   [./bucketsortCUDA, 256, 1048576, random]       g  BucketSort
# 2204706642   [./bucketsortCUDA, 512, 1048576, random]       g  BucketSort
# 3547712491  [./bucketsortCUDA, 1024, 1048576, random]       g  BucketSort
# 3707441980    [./bucketsortCUDA, 64, 1048576, random]       g  BucketSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 140327021              CUDA      int               4    1048576    random
# 2187979912             CUDA      int               4    1048576    random
# 2204706642             CUDA      int               4    1048576    random
# 3547712491             CUDA      int               4    1048576    random
# 3707441980             CUDA      int               4    1048576    random
#
#             num_procs  num_threads  num_blocks  group_num  \
# profile
# 140327021           1          128        8192         19
# 2187979912          1          256        4096         19
# 2204706642          1          512        2048         19
# 3547712491          1         1024        1024         19
# 3707441980          1           64       16384         19
#
#            implementation_source  Whole Computation Time
# profile
# 140327021            Handwritten                    0.55
# 2187979912           Handwritten                    0.57
# 2204706642           Handwritten                    0.53
# 3547712491           Handwritten                    0.56
# 3707441980           Handwritten                    0.54

# %%
gb = tk.groupby("InputSize")
# Out:
# 1  thickets created...
# {1048576: <thicket.thicket.Thicket object at 0x2ad7bea52fd0>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                                1048576  \
#                                                                    nid
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                1
#                                                    128               1
#                                                    256               1
#                                                    512               1
#                                                    1024              1
# {'name': 'comm', 'type': 'function'}               64                3
#                                                    128               3
#                                                    256               3
#                                                    512               3
#                                                    1024              3
# {'name': 'comm_large', 'type': 'function'}         64                4
#                                                    128               4
#                                                    256               4
#                                                    512               4
#                                                    1024              4
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64                8
#                                                    128               8
#                                                    256               8
#                                                    512               8
#                                                    1024              8
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64                5
#                                                    128               5
#                                                    256               5
#                                                    512               5
#                                                    1024              5
# {'name': 'comp', 'type': 'function'}               64                6
#                                                    128               6
#                                                    256               6
#                                                    512               6
#                                                    1024              6
# {'name': 'comp_large', 'type': 'function'}         64                7
#                                                    128               7
#                                                    256               7
#                                                    512               7
#                                                    1024              7
# {'name': 'correctness_check', 'type': 'function'}  64                9
#                                                    128               9
#                                                    256               9
#                                                    512               9
#                                                    1024              9
# {'name': 'data_init', 'type': 'function'}          64                2
#                                                    128               2
#                                                    256               2
#                                                    512               2
#                                                    1024              2
#
#                                                                                \
#                                                                  spot.channel
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'comm', 'type': 'function'}               64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}         64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'comp', 'type': 'function'}               64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}         64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'}  64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
# {'name': 'data_init', 'type': 'function'}          64           regionprofile
#                                                    128          regionprofile
#                                                    256          regionprofile
#                                                    512          regionprofile
#                                                    1024         regionprofile
#
#                                                                               \
#                                                                Min time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.774595
#                                                    128              0.618255
#                                                    256              0.761927
#                                                    512              0.982549
#                                                    1024             0.634789
# {'name': 'comm', 'type': 'function'}               64               0.001724
#                                                    128              0.001508
#                                                    256              0.001446
#                                                    512              0.001402
#                                                    1024             0.001524
# {'name': 'comm_large', 'type': 'function'}         64               0.001640
#                                                    128              0.001447
#                                                    256              0.001388
#                                                    512              0.001342
#                                                    1024             0.001467
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64               0.000363
#                                                    128              0.000425
#                                                    256              0.000374
#                                                    512              0.000317
#                                                    1024             0.000469
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64               0.001202
#                                                    128              0.000978
#                                                    256              0.000975
#                                                    512              0.000982
#                                                    1024             0.000960
# {'name': 'comp', 'type': 'function'}               64               0.253706
#                                                    128              0.249733
#                                                    256              0.249065
#                                                    512              0.249305
#                                                    1024             0.248447
# {'name': 'comp_large', 'type': 'function'}         64               0.253634
#                                                    128              0.249693
#                                                    256              0.249030
#                                                    512              0.249268
#                                                    1024             0.248411
# {'name': 'correctness_check', 'type': 'function'}  64               0.002981
#                                                    128              0.002971
#                                                    256              0.002960
#                                                    512              0.002948
#                                                    1024             0.004667
# {'name': 'data_init', 'type': 'function'}          64               0.022017
#                                                    128              0.022264
#                                                    256              0.021755
#                                                    512              0.022713
#                                                    1024             0.022155
#
#                                                                               \
#                                                                Max time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.774595
#                                                    128              0.618255
#                                                    256              0.761927
#                                                    512              0.982549
#                                                    1024             0.634789
# {'name': 'comm', 'type': 'function'}               64               0.001724
#                                                    128              0.001508
#                                                    256              0.001446
#                                                    512              0.001402
#                                                    1024             0.001524
# {'name': 'comm_large', 'type': 'function'}         64               0.001640
#                                                    128              0.001447
#                                                    256              0.001388
#                                                    512              0.001342
#                                                    1024             0.001467
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64               0.000363
#                                                    128              0.000425
#                                                    256              0.000374
#                                                    512              0.000317
#                                                    1024             0.000469
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64               0.001202
#                                                    128              0.000978
#                                                    256              0.000975
#                                                    512              0.000982
#                                                    1024             0.000960
# {'name': 'comp', 'type': 'function'}               64               0.253706
#                                                    128              0.249733
#                                                    256              0.249065
#                                                    512              0.249305
#                                                    1024             0.248447
# {'name': 'comp_large', 'type': 'function'}         64               0.253634
#                                                    128              0.249693
#                                                    256              0.249030
#                                                    512              0.249268
#                                                    1024             0.248411
# {'name': 'correctness_check', 'type': 'function'}  64               0.002981
#                                                    128              0.002971
#                                                    256              0.002960
#                                                    512              0.002948
#                                                    1024             0.004667
# {'name': 'data_init', 'type': 'function'}          64               0.022017
#                                                    128              0.022264
#                                                    256              0.021755
#                                                    512              0.022713
#                                                    1024             0.022155
#
#                                                                               \
#                                                                Avg time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64               0.774595
#                                                    128              0.618255
#                                                    256              0.761927
#                                                    512              0.982549
#                                                    1024             0.634789
# {'name': 'comm', 'type': 'function'}               64               0.001724
#                                                    128              0.001508
#                                                    256              0.001446
#                                                    512              0.001402
#                                                    1024             0.001524
# {'name': 'comm_large', 'type': 'function'}         64               0.001640
#                                                    128              0.001447
#                                                    256              0.001388
#                                                    512              0.001342
#                                                    1024             0.001467
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64               0.000363
#                                                    128              0.000425
#                                                    256              0.000374
#                                                    512              0.000317
#                                                    1024             0.000469
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64               0.001202
#                                                    128              0.000978
#                                                    256              0.000975
#                                                    512              0.000982
#                                                    1024             0.000960
# {'name': 'comp', 'type': 'function'}               64               0.253706
#                                                    128              0.249733
#                                                    256              0.249065
#                                                    512              0.249305
#                                                    1024             0.248447
# {'name': 'comp_large', 'type': 'function'}         64               0.253634
#                                                    128              0.249693
#                                                    256              0.249030
#                                                    512              0.249268
#                                                    1024             0.248411
# {'name': 'correctness_check', 'type': 'function'}  64               0.002981
#                                                    128              0.002971
#                                                    256              0.002960
#                                                    512              0.002948
#                                                    1024             0.004667
# {'name': 'data_init', 'type': 'function'}          64               0.022017
#                                                    128              0.022264
#                                                    256              0.021755
#                                                    512              0.022713
#                                                    1024             0.022155
#
#                                                                            \
#                                                                Total time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64            0.774595
#                                                    128           0.618255
#                                                    256           0.761927
#                                                    512           0.982549
#                                                    1024          0.634789
# {'name': 'comm', 'type': 'function'}               64            0.001724
#                                                    128           0.001508
#                                                    256           0.001446
#                                                    512           0.001402
#                                                    1024          0.001524
# {'name': 'comm_large', 'type': 'function'}         64            0.001640
#                                                    128           0.001447
#                                                    256           0.001388
#                                                    512           0.001342
#                                                    1024          0.001467
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64            0.000363
#                                                    128           0.000425
#                                                    256           0.000374
#                                                    512           0.000317
#                                                    1024          0.000469
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64            0.001202
#                                                    128           0.000978
#                                                    256           0.000975
#                                                    512           0.000982
#                                                    1024          0.000960
# {'name': 'comp', 'type': 'function'}               64            0.253706
#                                                    128           0.249733
#                                                    256           0.249065
#                                                    512           0.249305
#                                                    1024          0.248447
# {'name': 'comp_large', 'type': 'function'}         64            0.253634
#                                                    128           0.249693
#                                                    256           0.249030
#                                                    512           0.249268
#                                                    1024          0.248411
# {'name': 'correctness_check', 'type': 'function'}  64            0.002981
#                                                    128           0.002971
#                                                    256           0.002960
#                                                    512           0.002948
#                                                    1024          0.004667
# {'name': 'data_init', 'type': 'function'}          64            0.022017
#                                                    128           0.022264
#                                                    256           0.021755
#                                                    512           0.022713
#                                                    1024          0.022155
#
#                                                                                   \
#                                                                Avg GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.001333
#                                                    128                  0.001194
#                                                    256                  0.001144
#                                                    512                  0.001090
#                                                    1024                 0.001218
# {'name': 'comm', 'type': 'function'}               64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'comm_large', 'type': 'function'}         64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64                   0.000003
#                                                    128                  0.000003
#                                                    256                  0.000003
#                                                    512                  0.000003
#                                                    1024                 0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64                   0.000921
#                                                    128                  0.000759
#                                                    256                  0.000761
#                                                    512                  0.000756
#                                                    1024                 0.000741
# {'name': 'comp', 'type': 'function'}               64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'comp_large', 'type': 'function'}         64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'correctness_check', 'type': 'function'}  64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Min GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.001333
#                                                    128                  0.001194
#                                                    256                  0.001144
#                                                    512                  0.001090
#                                                    1024                 0.001218
# {'name': 'comm', 'type': 'function'}               64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'comm_large', 'type': 'function'}         64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64                   0.000003
#                                                    128                  0.000003
#                                                    256                  0.000003
#                                                    512                  0.000003
#                                                    1024                 0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64                   0.000921
#                                                    128                  0.000759
#                                                    256                  0.000761
#                                                    512                  0.000756
#                                                    1024                 0.000741
# {'name': 'comp', 'type': 'function'}               64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'comp_large', 'type': 'function'}         64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'correctness_check', 'type': 'function'}  64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
#
#                                                                                   \
#                                                                Max GPU time/rank
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                   0.001333
#                                                    128                  0.001194
#                                                    256                  0.001144
#                                                    512                  0.001090
#                                                    1024                 0.001218
# {'name': 'comm', 'type': 'function'}               64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'comm_large', 'type': 'function'}         64                   0.000924
#                                                    128                  0.000762
#                                                    256                  0.000764
#                                                    512                  0.000759
#                                                    1024                 0.000744
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64                   0.000003
#                                                    128                  0.000003
#                                                    256                  0.000003
#                                                    512                  0.000003
#                                                    1024                 0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64                   0.000921
#                                                    128                  0.000759
#                                                    256                  0.000761
#                                                    512                  0.000756
#                                                    1024                 0.000741
# {'name': 'comp', 'type': 'function'}               64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'comp_large', 'type': 'function'}         64                   0.000409
#                                                    128                  0.000431
#                                                    256                  0.000380
#                                                    512                  0.000331
#                                                    1024                 0.000474
# {'name': 'correctness_check', 'type': 'function'}  64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
# {'name': 'data_init', 'type': 'function'}          64                        NaN
#                                                    128                       NaN
#                                                    256                       NaN
#                                                    512                       NaN
#                                                    1024                      NaN
#
#                                                                                \
#                                                                Total GPU time
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                0.001333
#                                                    128               0.001194
#                                                    256               0.001144
#                                                    512               0.001090
#                                                    1024              0.001218
# {'name': 'comm', 'type': 'function'}               64                0.000924
#                                                    128               0.000762
#                                                    256               0.000764
#                                                    512               0.000759
#                                                    1024              0.000744
# {'name': 'comm_large', 'type': 'function'}         64                0.000924
#                                                    128               0.000762
#                                                    256               0.000764
#                                                    512               0.000759
#                                                    1024              0.000744
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64                0.000003
#                                                    128               0.000003
#                                                    256               0.000003
#                                                    512               0.000003
#                                                    1024              0.000003
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64                0.000921
#                                                    128               0.000759
#                                                    256               0.000761
#                                                    512               0.000756
#                                                    1024              0.000741
# {'name': 'comp', 'type': 'function'}               64                0.000409
#                                                    128               0.000431
#                                                    256               0.000380
#                                                    512               0.000331
#                                                    1024              0.000474
# {'name': 'comp_large', 'type': 'function'}         64                0.000409
#                                                    128               0.000431
#                                                    256               0.000380
#                                                    512               0.000331
#                                                    1024              0.000474
# {'name': 'correctness_check', 'type': 'function'}  64                     NaN
#                                                    128                    NaN
#                                                    256                    NaN
#                                                    512                    NaN
#                                                    1024                   NaN
# {'name': 'data_init', 'type': 'function'}          64                     NaN
#                                                    128                    NaN
#                                                    256                    NaN
#                                                    512                    NaN
#                                                    1024                   NaN
#
#                                                                                      name
#
# node                                               num_threads
# {'name': 'main', 'type': 'function'}               64                                main
#                                                    128                               main
#                                                    256                               main
#                                                    512                               main
#                                                    1024                              main
# {'name': 'comm', 'type': 'function'}               64                                comm
#                                                    128                               comm
#                                                    256                               comm
#                                                    512                               comm
#                                                    1024                              comm
# {'name': 'comm_large', 'type': 'function'}         64                          comm_large
#                                                    128                         comm_large
#                                                    256                         comm_large
#                                                    512                         comm_large
#                                                    1024                        comm_large
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64           cudaMemcpy_device_to_host
#                                                    128          cudaMemcpy_device_to_host
#                                                    256          cudaMemcpy_device_to_host
#                                                    512          cudaMemcpy_device_to_host
#                                                    1024         cudaMemcpy_device_to_host
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64           cudaMemcpy_host_to_device
#                                                    128          cudaMemcpy_host_to_device
#                                                    256          cudaMemcpy_host_to_device
#                                                    512          cudaMemcpy_host_to_device
#                                                    1024         cudaMemcpy_host_to_device
# {'name': 'comp', 'type': 'function'}               64                                comp
#                                                    128                               comp
#                                                    256                               comp
#                                                    512                               comp
#                                                    1024                              comp
# {'name': 'comp_large', 'type': 'function'}         64                          comp_large
#                                                    128                         comp_large
#                                                    256                         comp_large
#                                                    512                         comp_large
#                                                    1024                        comp_large
# {'name': 'correctness_check', 'type': 'function'}  64                   correctness_check
#                                                    128                  correctness_check
#                                                    256                  correctness_check
#                                                    512                  correctness_check
#                                                    1024                 correctness_check
# {'name': 'data_init', 'type': 'function'}          64                           data_init
#                                                    128                          data_init
#                                                    256                          data_init
#                                                    512                          data_init
#                                                    1024                         data_init

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (1048576, "nid"), (1048576, "spot.channel")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
ctk.dataframe
# Out:
#                                             1048576                \
#                                       Min time/rank Max time/rank
# name                      num_threads
# main                      64               0.774595      0.774595
#                           128              0.618255      0.618255
#                           256              0.761927      0.761927
#                           512              0.982549      0.982549
#                           1024             0.634789      0.634789
# comm                      64               0.001724      0.001724
#                           128              0.001508      0.001508
#                           256              0.001446      0.001446
#                           512              0.001402      0.001402
#                           1024             0.001524      0.001524
# comm_large                64               0.001640      0.001640
#                           128              0.001447      0.001447
#                           256              0.001388      0.001388
#                           512              0.001342      0.001342
#                           1024             0.001467      0.001467
# cudaMemcpy_device_to_host 64               0.000363      0.000363
#                           128              0.000425      0.000425
#                           256              0.000374      0.000374
#                           512              0.000317      0.000317
#                           1024             0.000469      0.000469
# cudaMemcpy_host_to_device 64               0.001202      0.001202
#                           128              0.000978      0.000978
#                           256              0.000975      0.000975
#                           512              0.000982      0.000982
#                           1024             0.000960      0.000960
# comp                      64               0.253706      0.253706
#                           128              0.249733      0.249733
#                           256              0.249065      0.249065
#                           512              0.249305      0.249305
#                           1024             0.248447      0.248447
# comp_large                64               0.253634      0.253634
#                           128              0.249693      0.249693
#                           256              0.249030      0.249030
#                           512              0.249268      0.249268
#                           1024             0.248411      0.248411
# correctness_check         64               0.002981      0.002981
#                           128              0.002971      0.002971
#                           256              0.002960      0.002960
#                           512              0.002948      0.002948
#                           1024             0.004667      0.004667
# data_init                 64               0.022017      0.022017
#                           128              0.022264      0.022264
#                           256              0.021755      0.021755
#                           512              0.022713      0.022713
#                           1024             0.022155      0.022155
#
#                                                                 \
#                                       Avg time/rank Total time
# name                      num_threads
# main                      64               0.774595   0.774595
#                           128              0.618255   0.618255
#                           256              0.761927   0.761927
#                           512              0.982549   0.982549
#                           1024             0.634789   0.634789
# comm                      64               0.001724   0.001724
#                           128              0.001508   0.001508
#                           256              0.001446   0.001446
#                           512              0.001402   0.001402
#                           1024             0.001524   0.001524
# comm_large                64               0.001640   0.001640
#                           128              0.001447   0.001447
#                           256              0.001388   0.001388
#                           512              0.001342   0.001342
#                           1024             0.001467   0.001467
# cudaMemcpy_device_to_host 64               0.000363   0.000363
#                           128              0.000425   0.000425
#                           256              0.000374   0.000374
#                           512              0.000317   0.000317
#                           1024             0.000469   0.000469
# cudaMemcpy_host_to_device 64               0.001202   0.001202
#                           128              0.000978   0.000978
#                           256              0.000975   0.000975
#                           512              0.000982   0.000982
#                           1024             0.000960   0.000960
# comp                      64               0.253706   0.253706
#                           128              0.249733   0.249733
#                           256              0.249065   0.249065
#                           512              0.249305   0.249305
#                           1024             0.248447   0.248447
# comp_large                64               0.253634   0.253634
#                           128              0.249693   0.249693
#                           256              0.249030   0.249030
#                           512              0.249268   0.249268
#                           1024             0.248411   0.248411
# correctness_check         64               0.002981   0.002981
#                           128              0.002971   0.002971
#                           256              0.002960   0.002960
#                           512              0.002948   0.002948
#                           1024             0.004667   0.004667
# data_init                 64               0.022017   0.022017
#                           128              0.022264   0.022264
#                           256              0.021755   0.021755
#                           512              0.022713   0.022713
#                           1024             0.022155   0.022155
#
#                                                                            \
#                                       Avg GPU time/rank Min GPU time/rank
# name                      num_threads
# main                      64                   0.001333          0.001333
#                           128                  0.001194          0.001194
#                           256                  0.001144          0.001144
#                           512                  0.001090          0.001090
#                           1024                 0.001218          0.001218
# comm                      64                   0.000924          0.000924
#                           128                  0.000762          0.000762
#                           256                  0.000764          0.000764
#                           512                  0.000759          0.000759
#                           1024                 0.000744          0.000744
# comm_large                64                   0.000924          0.000924
#                           128                  0.000762          0.000762
#                           256                  0.000764          0.000764
#                           512                  0.000759          0.000759
#                           1024                 0.000744          0.000744
# cudaMemcpy_device_to_host 64                   0.000003          0.000003
#                           128                  0.000003          0.000003
#                           256                  0.000003          0.000003
#                           512                  0.000003          0.000003
#                           1024                 0.000003          0.000003
# cudaMemcpy_host_to_device 64                   0.000921          0.000921
#                           128                  0.000759          0.000759
#                           256                  0.000761          0.000761
#                           512                  0.000756          0.000756
#                           1024                 0.000741          0.000741
# comp                      64                   0.000409          0.000409
#                           128                  0.000431          0.000431
#                           256                  0.000380          0.000380
#                           512                  0.000331          0.000331
#                           1024                 0.000474          0.000474
# comp_large                64                   0.000409          0.000409
#                           128                  0.000431          0.000431
#                           256                  0.000380          0.000380
#                           512                  0.000331          0.000331
#                           1024                 0.000474          0.000474
# correctness_check         64                        NaN               NaN
#                           128                       NaN               NaN
#                           256                       NaN               NaN
#                           512                       NaN               NaN
#                           1024                      NaN               NaN
# data_init                 64                        NaN               NaN
#                           128                       NaN               NaN
#                           256                       NaN               NaN
#                           512                       NaN               NaN
#                           1024                      NaN               NaN
#
#
#                                       Max GPU time/rank Total GPU time
# name                      num_threads
# main                      64                   0.001333       0.001333
#                           128                  0.001194       0.001194
#                           256                  0.001144       0.001144
#                           512                  0.001090       0.001090
#                           1024                 0.001218       0.001218
# comm                      64                   0.000924       0.000924
#                           128                  0.000762       0.000762
#                           256                  0.000764       0.000764
#                           512                  0.000759       0.000759
#                           1024                 0.000744       0.000744
# comm_large                64                   0.000924       0.000924
#                           128                  0.000762       0.000762
#                           256                  0.000764       0.000764
#                           512                  0.000759       0.000759
#                           1024                 0.000744       0.000744
# cudaMemcpy_device_to_host 64                   0.000003       0.000003
#                           128                  0.000003       0.000003
#                           256                  0.000003       0.000003
#                           512                  0.000003       0.000003
#                           1024                 0.000003       0.000003
# cudaMemcpy_host_to_device 64                   0.000921       0.000921
#                           128                  0.000759       0.000759
#                           256                  0.000761       0.000761
#                           512                  0.000756       0.000756
#                           1024                 0.000741       0.000741
# comp                      64                   0.000409       0.000409
#                           128                  0.000431       0.000431
#                           256                  0.000380       0.000380
#                           512                  0.000331       0.000331
#                           1024                 0.000474       0.000474
# comp_large                64                   0.000409       0.000409
#                           128                  0.000431       0.000431
#                           256                  0.000380       0.000380
#                           512                  0.000331       0.000331
#                           1024                 0.000474       0.000474
# correctness_check         64                        NaN            NaN
#                           128                       NaN            NaN
#                           256                       NaN            NaN
#                           512                       NaN            NaN
#                           1024                      NaN            NaN
# data_init                 64                        NaN            NaN
#                           128                       NaN            NaN
#                           256                       NaN            NaN
#                           512                       NaN            NaN
#                           1024                      NaN            NaN

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
print(function_names)
processes = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
print(processes)
array_sizes = [65536, 262144, 1048576] # append as necessary
print(array_sizes)
# Out:
# {'data_init', 'comm', 'cudaMemcpy_device_to_host', 'comp', 'comm_large', 'comp_large', 'cudaMemcpy_host_to_device', 'correctness_check', 'main'}
# [64, 128, 256, 512, 1024]
# [65536, 262144, 1048576]

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    ax.plot(
        df[0],
        marker='o',
    )
    
    ax.plot(
        df[1],
        marker='o',
    )
    
    ax.plot(
        df[2],
        marker='o',
    )
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.grid(True)
    plt.legend(["Min GPU time/rank", "Max GPU time/rank", "Avg GPU time/rank"]) 
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    plt.show()
    return fig, ax

# %%
print(ctk.dataframe.loc["main"][1048576])
# Out:
#              Min time/rank  Max time/rank  Avg time/rank  Total time  \
# num_threads
# 64                0.774595       0.774595       0.774595    0.774595
# 128               0.618255       0.618255       0.618255    0.618255
# 256               0.761927       0.761927       0.761927    0.761927
# 512               0.982549       0.982549       0.982549    0.982549
# 1024              0.634789       0.634789       0.634789    0.634789
#
#              Avg GPU time/rank  Min GPU time/rank  Max GPU time/rank  \
# num_threads
# 64                    0.001333           0.001333           0.001333
# 128                   0.001194           0.001194           0.001194
# 256                   0.001144           0.001144           0.001144
# 512                   0.001090           0.001090           0.001090
# 1024                  0.001218           0.001218           0.001218
#
#              Total GPU time
# num_threads
# 64                 0.001333
# 128                0.001194
# 256                0.001144
# 512                0.001090
# 1024               0.001218

# %%
name = "main"
arraySize = 1048576
plot_mpl(
    df=[ctk.dataframe.loc[name][arraySize]["Min GPU time/rank"],
        ctk.dataframe.loc[name][arraySize]["Max GPU time/rank"],
        ctk.dataframe.loc[name][arraySize]["Avg GPU time/rank"]
        ], 
    title="CUDA Bucket Sort {} Time for Array Size {} on Sorted Data".format(name, arraySize),
    xlabel="Threads",
    ylabel="Time (seconds)",
)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'CUDA Bucket Sort main Time for Array Size 1048576 on Sorted Data'}, xlabel='Threads', ylabel='Time (seconds)'>)
