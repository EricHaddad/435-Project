# %% [markdown]
# # Lab 1 Analysis Example using Thicket

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk = th.Thicket.from_caliperreader(glob("*random.cali")) # dividing it by input type for now
tk.statsframe.dataframe["time"] = 1

# %%
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 correctness_check
# 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# Performance data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414    3
#                                                   2998253537    3
#                                                   3199878523    3
#                                                   3634518157    3
# {'name': 'data_init', 'type': 'function'}         1438567414    1
#                                                   2998253537    1
#                                                   3199878523    1
#                                                   3634518157    1
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414  regionprofile
#                                                   2998253537  regionprofile
#                                                   3199878523  regionprofile
#                                                   3634518157  regionprofile
# {'name': 'data_init', 'type': 'function'}         1438567414  regionprofile
#                                                   2998253537  regionprofile
#                                                   3199878523  regionprofile
#                                                   3634518157  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414       0.000053
#                                                   2998253537       0.000051
#                                                   3199878523       0.000048
#                                                   3634518157       0.000058
# {'name': 'data_init', 'type': 'function'}         1438567414       0.000246
#                                                   2998253537       0.000244
#                                                   3199878523       0.000237
#                                                   3634518157       0.000251
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414       0.000053
#                                                   2998253537       0.000051
#                                                   3199878523       0.000048
#                                                   3634518157       0.000058
# {'name': 'data_init', 'type': 'function'}         1438567414       0.000246
#                                                   2998253537       0.000244
#                                                   3199878523       0.000237
#                                                   3634518157       0.000251
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414       0.000053
#                                                   2998253537       0.000051
#                                                   3199878523       0.000048
#                                                   3634518157       0.000058
# {'name': 'data_init', 'type': 'function'}         1438567414       0.000246
#                                                   2998253537       0.000244
#                                                   3199878523       0.000237
#                                                   3634518157       0.000251
#
#                                                               Total time  \
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414    0.000053
#                                                   2998253537    0.000051
#                                                   3199878523    0.000048
#                                                   3634518157    0.000058
# {'name': 'data_init', 'type': 'function'}         1438567414    0.000246
#                                                   2998253537    0.000244
#                                                   3199878523    0.000237
#                                                   3634518157    0.000251
#
#                                                                            name
# node                                              profile
# {'name': 'correctness_check', 'type': 'function'} 1438567414  correctness_check
#                                                   2998253537  correctness_check
#                                                   3199878523  correctness_check
#                                                   3634518157  correctness_check
# {'name': 'data_init', 'type': 'function'}         1438567414          data_init
#                                                   2998253537          data_init
#                                                   3199878523          data_init
#                                                   3634518157          data_init

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 1438567414           2.11.0-dev
# 2998253537           2.11.0-dev
# 3199878523           2.11.0-dev
# 3634518157           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 1438567414  min#inclusive#sum#time.duration,max#inclusive#...
# 2998253537  min#inclusive#sum#time.duration,max#inclusive#...
# 3199878523  min#inclusive#sum#time.duration,max#inclusive#...
# 3634518157  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 1438567414                                            2
# 2998253537                                            2
# 3199878523                                            2
# 3634518157                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 1438567414  cuda.gputime,node.order  regionprofile         spot
# 2998253537  cuda.gputime,node.order  regionprofile         spot
# 3199878523  cuda.gputime,node.order  regionprofile         spot
# 3634518157  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order            spot:output  \
# profile
# 1438567414              true            true   t8-v1024-random.cali
# 2998253537              true            true   t2-v1024-random.cali
# 3199878523              true            true  t16-v1024-random.cali
# 3634518157              true            true   t4-v1024-random.cali
#
#             launchdate                                          libraries  \
# profile
# 1438567414  1700109492  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2998253537  1700108239  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3199878523  1700109499  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3634518157  1700109471  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                         cmdline cluster  Algorithm  \
# profile
# 1438567414   [./MergeSortCUDA, 8, 1024, random]       g  MergeSort
# 2998253537   [./MergeSortCUDA, 2, 1024, random]       g  MergeSort
# 3199878523  [./MergeSortCUDA, 16, 1024, random]       g  MergeSort
# 3634518157   [./MergeSortCUDA, 4, 1024, random]       g  MergeSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 1438567414             CUDA      int               4       1024    random
# 2998253537             CUDA      int               4       1024    random
# 3199878523             CUDA      int               4       1024    random
# 3634518157             CUDA      int               4       1024    random
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 1438567414            8         128          1           Handwritten
# 2998253537            2         512          1           Handwritten
# 3199878523           16          64          1           Handwritten
# 3634518157            4         256          1           Handwritten

# %%
gb = tk.groupby("InputSize")
# Out:
# 1  thickets created...
# {1024: <thicket.thicket.Thicket object at 0x2ace34c35610>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               1024  \
#                                                                nid
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2              3
#                                                   4              3
#                                                   8              3
#                                                   16             3
# {'name': 'data_init', 'type': 'function'}         2              1
#                                                   4              1
#                                                   8              1
#                                                   16             1
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2            regionprofile
#                                                   4            regionprofile
#                                                   8            regionprofile
#                                                   16           regionprofile
# {'name': 'data_init', 'type': 'function'}         2            regionprofile
#                                                   4            regionprofile
#                                                   8            regionprofile
#                                                   16           regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2                0.000051
#                                                   4                0.000058
#                                                   8                0.000053
#                                                   16               0.000048
# {'name': 'data_init', 'type': 'function'}         2                0.000244
#                                                   4                0.000251
#                                                   8                0.000246
#                                                   16               0.000237
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2                0.000051
#                                                   4                0.000058
#                                                   8                0.000053
#                                                   16               0.000048
# {'name': 'data_init', 'type': 'function'}         2                0.000244
#                                                   4                0.000251
#                                                   8                0.000246
#                                                   16               0.000237
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2                0.000051
#                                                   4                0.000058
#                                                   8                0.000053
#                                                   16               0.000048
# {'name': 'data_init', 'type': 'function'}         2                0.000244
#                                                   4                0.000251
#                                                   8                0.000246
#                                                   16               0.000237
#
#                                                                           \
#                                                               Total time
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2             0.000051
#                                                   4             0.000058
#                                                   8             0.000053
#                                                   16            0.000048
# {'name': 'data_init', 'type': 'function'}         2             0.000244
#                                                   4             0.000251
#                                                   8             0.000246
#                                                   16            0.000237
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'correctness_check', 'type': 'function'} 2            correctness_check
#                                                   4            correctness_check
#                                                   8            correctness_check
#                                                   16           correctness_check
# {'name': 'data_init', 'type': 'function'}         2                    data_init
#                                                   4                    data_init
#                                                   8                    data_init
#                                                   16                   data_init

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (1024, "nid"), (1024, "spot.channel")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
ctk.dataframe
# Out:
#                                        1024                              \
#                               Min time/rank Max time/rank Avg time/rank
# name              num_threads
# correctness_check 2                0.000051      0.000051      0.000051
#                   4                0.000058      0.000058      0.000058
#                   8                0.000053      0.000053      0.000053
#                   16               0.000048      0.000048      0.000048
# data_init         2                0.000244      0.000244      0.000244
#                   4                0.000251      0.000251      0.000251
#                   8                0.000246      0.000246      0.000246
#                   16               0.000237      0.000237      0.000237
#
#
#                               Total time
# name              num_threads
# correctness_check 2             0.000051
#                   4             0.000058
#                   8             0.000053
#                   16            0.000048
# data_init         2             0.000244
#                   4             0.000251
#                   8             0.000246
#                   16            0.000237

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
print(function_names)
processes = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
print(processes)
array_sizes = [1024] # append as necessary
print(array_sizes)
# Out:
# {'correctness_check', 'data_init'}
# [2, 4, 8, 16]
# [1024]

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    ax.plot(
        df[0],
        marker='o',
    )
    
    ax.plot(
        df[1],
        marker='o',
    )
    
    ax.plot(
        df[2],
        marker='o',
    )
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.grid(True)
    plt.legend(["Min GPU time/rank", "Max GPU time/rank", "Avg GPU time/rank"]) 
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    plt.show()
    return fig, ax

# %%
print(ctk.dataframe.loc["main"][1024])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-d8c23c4bcd90> in <module>
# ----> 1 print(ctk.dataframe.loc["main"][1024])
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3731         if isinstance(index, MultiIndex):
#    3732             try:
# -> 3733                 loc, new_index = index._get_loc_level(
#    3734                     key, level=0, drop_level=drop_level
#    3735                 )
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_level(self, key, level, drop_level)
#    3066                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    3067         else:
# -> 3068             indexer = self._get_level_indexer(key, level=level)
#    3069             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    3070
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3156         else:
#    3157
# -> 3158             idx = self._get_loc_single_level_index(level_index, key)
#    3159
#    3160             if level > 0 or self.lexsort_depth == 0:
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2807             return -1
#    2808         else:
# -> 2809             return level_index.get_loc(key)
#    2810
#    2811     def get_loc(self, key, method=None):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'main'

# %%
name = "main"
arraySize = 1024
plot_mpl(
    df=[ctk.dataframe.loc[name][arraySize]["Min GPU time/rank"],
        ctk.dataframe.loc[name][arraySize]["Max GPU time/rank"],
        ctk.dataframe.loc[name][arraySize]["Avg GPU time/rank"]
        ], 
    title="CUDA Merge Sort {} Time for Array Size {} on Sorted Data".format(name, arraySize),
    xlabel="Threads",
    ylabel="Time (seconds)",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'main'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-c36a260865ef> in <module>
#       2 arraySize = 1024
#       3 plot_mpl(
# ----> 4     df=[ctk.dataframe.loc[name][arraySize]["Min GPU time/rank"],
#       5         ctk.dataframe.loc[name][arraySize]["Max GPU time/rank"],
#       6         ctk.dataframe.loc[name][arraySize]["Avg GPU time/rank"]
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3731         if isinstance(index, MultiIndex):
#    3732             try:
# -> 3733                 loc, new_index = index._get_loc_level(
#    3734                     key, level=0, drop_level=drop_level
#    3735                 )
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_level(self, key, level, drop_level)
#    3066                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    3067         else:
# -> 3068             indexer = self._get_level_indexer(key, level=level)
#    3069             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    3070
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3156         else:
#    3157
# -> 3158             idx = self._get_loc_single_level_index(level_index, key)
#    3159
#    3160             if level > 0 or self.lexsort_depth == 0:
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2807             return -1
#    2808         else:
# -> 2809             return level_index.get_loc(key)
#    2810
#    2811     def get_loc(self, key, method=None):
#
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'main'
