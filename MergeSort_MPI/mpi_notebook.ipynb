# %% [markdown]
# # MPI Notebook

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Read in all the files

# %%
tk_random = th.Thicket.from_caliperreader(glob("*random.cali"))
tk_random.statsframe.dataframe["time"] = 1
gb_random = tk_random.groupby("InputSize")
ctk_random = th.Thicket.concat_thickets(
    thickets=list(gb_random.values()),
    headers=list(gb_random.keys()),
    axis="columns",
    metadata_key="num_procs"
)
# Drop unwanted columns
ctk_random.dataframe = ctk_random.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (262144, "nid"), (1048576, "nid"), (4194304, "nid"), (16777216, "nid"), (67108864, "nid"), (268435456, "nid")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.drop([(65536, "Min time/rank"), (262144, "Min time/rank"), (1048576, "Min time/rank"), (4194304, "Min time/rank"), (16777216, "Min time/rank"), (67108864, "Min time/rank"), (268435456, "Min time/rank")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.drop([(65536, "Max time/rank"), (262144, "Max time/rank"), (1048576, "Max time/rank"), (4194304, "Max time/rank"), (16777216, "Max time/rank"), (67108864, "Max time/rank"), (268435456, "Max time/rank")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.drop([(65536, "Total time"), (262144, "Total time"), (1048576, "Total time"), (4194304, "Total time"), (16777216, "Total time"), (67108864, "Total time"), (268435456, "Total time")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.drop([(65536, "Variance time/rank"), (262144, "Variance time/rank"), (1048576, "Variance time/rank"), (4194304, "Variance time/rank"), (16777216, "Variance time/rank"), (67108864, "Variance time/rank"), (268435456, "Variance time/rank")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.drop([(65536, "spot.channel"), (262144, "spot.channel"), (1048576, "spot.channel"), (4194304, "spot.channel"), (16777216, "spot.channel"), (67108864, "spot.channel"), (268435456, "spot.channel")], axis=1)
ctk_random.dataframe = ctk_random.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac726ab2d00>, 262144: <thicket.thicket.Thicket object at 0x2ac726b87700>, 1048576: <thicket.thicket.Thicket object at 0x2ac726c8e250>, 4194304: <thicket.thicket.Thicket object at 0x2ac726bf2400>, 16777216: <thicket.thicket.Thicket object at 0x2ac726cef430>, 67108864: <thicket.thicket.Thicket object at 0x2ac726b0e550>, 268435456: <thicket.thicket.Thicket object at 0x2ac726d06c40>}

# %%
tk_reverse = th.Thicket.from_caliperreader(glob("*reverse.cali"))
tk_reverse.statsframe.dataframe["time"] = 1
gb_reverse = tk_reverse.groupby("InputSize")
ctk_reverse = th.Thicket.concat_thickets(
    thickets=list(gb_reverse.values()),
    headers=list(gb_reverse.keys()),
    axis="columns",
    metadata_key="num_procs"
)
# Drop unwanted columns
ctk_reverse.dataframe = ctk_reverse.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (262144, "nid"), (1048576, "nid"), (4194304, "nid"), (16777216, "nid"), (67108864, "nid"), (268435456, "nid")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.drop([(65536, "Min time/rank"), (262144, "Min time/rank"), (1048576, "Min time/rank"), (4194304, "Min time/rank"), (16777216, "Min time/rank"), (67108864, "Min time/rank"), (268435456, "Min time/rank")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.drop([(65536, "Max time/rank"), (262144, "Max time/rank"), (1048576, "Max time/rank"), (4194304, "Max time/rank"), (16777216, "Max time/rank"), (67108864, "Max time/rank"), (268435456, "Max time/rank")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.drop([(65536, "Total time"), (262144, "Total time"), (1048576, "Total time"), (4194304, "Total time"), (16777216, "Total time"), (67108864, "Total time"), (268435456, "Total time")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.drop([(65536, "Variance time/rank"), (262144, "Variance time/rank"), (1048576, "Variance time/rank"), (4194304, "Variance time/rank"), (16777216, "Variance time/rank"), (67108864, "Variance time/rank"), (268435456, "Variance time/rank")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.drop([(65536, "spot.channel"), (262144, "spot.channel"), (1048576, "spot.channel"), (4194304, "spot.channel"), (16777216, "spot.channel"), (67108864, "spot.channel"), (268435456, "spot.channel")], axis=1)
ctk_reverse.dataframe = ctk_reverse.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac726fdfd30>, 262144: <thicket.thicket.Thicket object at 0x2ac727032e80>, 1048576: <thicket.thicket.Thicket object at 0x2ac726f23c40>, 4194304: <thicket.thicket.Thicket object at 0x2ac72707e400>, 16777216: <thicket.thicket.Thicket object at 0x2ac726fb4d90>, 67108864: <thicket.thicket.Thicket object at 0x2ac726ad4250>, 268435456: <thicket.thicket.Thicket object at 0x2ac726b0ebe0>}

# %%
tk_sorted = th.Thicket.from_caliperreader(glob("*sorted.cali"))
tk_sorted.statsframe.dataframe["time"] = 1
gb_sorted = tk_sorted.groupby("InputSize")
ctk_sorted = th.Thicket.concat_thickets(
    thickets=list(gb_sorted.values()),
    headers=list(gb_sorted.keys()),
    axis="columns",
    metadata_key="num_procs"
)
# Drop unwanted columns
ctk_sorted.dataframe = ctk_sorted.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (262144, "nid"), (1048576, "nid"), (4194304, "nid"), (16777216, "nid"), (67108864, "nid"), (268435456, "nid")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.drop([(65536, "Min time/rank"), (262144, "Min time/rank"), (1048576, "Min time/rank"), (4194304, "Min time/rank"), (16777216, "Min time/rank"), (67108864, "Min time/rank"), (268435456, "Min time/rank")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.drop([(65536, "Max time/rank"), (262144, "Max time/rank"), (1048576, "Max time/rank"), (4194304, "Max time/rank"), (16777216, "Max time/rank"), (67108864, "Max time/rank"), (268435456, "Max time/rank")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.drop([(65536, "Total time"), (262144, "Total time"), (1048576, "Total time"), (4194304, "Total time"), (16777216, "Total time"), (67108864, "Total time"), (268435456, "Total time")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.drop([(65536, "Variance time/rank"), (262144, "Variance time/rank"), (1048576, "Variance time/rank"), (4194304, "Variance time/rank"), (16777216, "Variance time/rank"), (67108864, "Variance time/rank"), (268435456, "Variance time/rank")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.drop([(65536, "spot.channel"), (262144, "spot.channel"), (1048576, "spot.channel"), (4194304, "spot.channel"), (16777216, "spot.channel"), (67108864, "spot.channel"), (268435456, "spot.channel")], axis=1)
ctk_sorted.dataframe = ctk_sorted.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac726e9a2e0>, 262144: <thicket.thicket.Thicket object at 0x2ac7271328e0>, 1048576: <thicket.thicket.Thicket object at 0x2ac726ceff70>, 4194304: <thicket.thicket.Thicket object at 0x2ac726b282b0>, 16777216: <thicket.thicket.Thicket object at 0x2ac727032400>, 67108864: <thicket.thicket.Thicket object at 0x2ac72716d340>, 268435456: <thicket.thicket.Thicket object at 0x2ac726f36fa0>}

# %%
tk_perturbed = th.Thicket.from_caliperreader(glob("*perturbed.cali"))
tk_perturbed.statsframe.dataframe["time"] = 1
gb_perturbed = tk_perturbed.groupby("InputSize")
ctk_perturbed = th.Thicket.concat_thickets(
    thickets=list(gb_perturbed.values()),
    headers=list(gb_perturbed.keys()),
    axis="columns",
    metadata_key="num_procs"
)
# Drop unwanted columns
ctk_perturbed.dataframe = ctk_perturbed.dataframe.reset_index().drop([("node", ""), (65536, "nid"), (262144, "nid"), (1048576, "nid"), (4194304, "nid"), (16777216, "nid"), (67108864, "nid"), (268435456, "nid")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.drop([(65536, "Min time/rank"), (262144, "Min time/rank"), (1048576, "Min time/rank"), (4194304, "Min time/rank"), (16777216, "Min time/rank"), (67108864, "Min time/rank"), (268435456, "Min time/rank")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.drop([(65536, "Max time/rank"), (262144, "Max time/rank"), (1048576, "Max time/rank"), (4194304, "Max time/rank"), (16777216, "Max time/rank"), (67108864, "Max time/rank"), (268435456, "Max time/rank")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.drop([(65536, "Total time"), (262144, "Total time"), (1048576, "Total time"), (4194304, "Total time"), (16777216, "Total time"), (67108864, "Total time"), (268435456, "Total time")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.drop([(65536, "Variance time/rank"), (262144, "Variance time/rank"), (1048576, "Variance time/rank"), (4194304, "Variance time/rank"), (16777216, "Variance time/rank"), (67108864, "Variance time/rank"), (268435456, "Variance time/rank")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.drop([(65536, "spot.channel"), (262144, "spot.channel"), (1048576, "spot.channel"), (4194304, "spot.channel"), (16777216, "spot.channel"), (67108864, "spot.channel"), (268435456, "spot.channel")], axis=1)
ctk_perturbed.dataframe = ctk_perturbed.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2ac7271addc0>, 262144: <thicket.thicket.Thicket object at 0x2ac726fbda30>, 1048576: <thicket.thicket.Thicket object at 0x2ac726f13ee0>, 4194304: <thicket.thicket.Thicket object at 0x2ac726e25e50>, 16777216: <thicket.thicket.Thicket object at 0x2ac726c6cac0>, 67108864: <thicket.thicket.Thicket object at 0x2ac726df3f70>, 268435456: <thicket.thicket.Thicket object at 0x2ac7271d48e0>}

# %% [markdown]
# Groupby matrix size argument, available in the metadata (tk.metadata) to organize our performance data into 3 groupings.

# %%
# Define common variables
#function_names = set(ctk.dataframe.index.get_level_values("name"))
function_names = ["comp_large", "comm", "main"]
print(function_names)
processes = sorted(list(set(ctk_random.dataframe.index.get_level_values("num_procs"))))
print(processes)
array_sizes = [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456] # append as necessary
print(array_sizes)
# Out:
# ['comp_large', 'comm', 'main']
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
# [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]

# %%
ctk_random.dataframe.loc["comp"]
# Out:
#               65536         262144        1048576       4194304    \
#           Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# num_procs
# 2              0.012875      0.088909      0.407786      1.752726
# 4              0.041858      0.176011      0.828022      3.517702
# 8              0.069529      0.383072      1.652224      7.052054
# 16             0.129538      0.743085      3.338644     14.083996
# 32             0.321574      1.537069      6.645719     28.133876
# 64             0.689846      3.046471     13.425485     56.814362
# 128            0.579500      3.115115     13.133447     56.837513
# 256            0.693453      2.994298     13.549798     56.693577
# 512            0.678469      2.956147     13.359609     56.425225
# 1024           1.430300      6.136493     26.684498    114.691996
#
#               16777216      67108864      268435456
#           Avg time/rank Avg time/rank Avg time/rank
# num_procs
# ...

# %% [markdown]
# # Weak Scale Plotting

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    ax.plot(
        df,
        marker='o',
    )
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.grid(True)
    plt.legend(array_sizes) 
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    plt.show()
    return fig, ax

# %%
for name in function_names:
    plot_mpl(
        df=ctk_sorted.dataframe.loc[name], # change ctk_* to whatever input type
        title="MPI Merge Sort {} Time on Sorted Data".format(name), # change title to reflect input type
        xlabel="Ranks",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# # Strong Scale Plotting

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    ax.plot(
        df[0],
        marker='o',
    )
    

    ax.plot(
        df[1],
        marker='o',
    )
    
    ax.plot(
        df[2],
        marker='o',
    )
    
    ax.plot(
        df[3],
        marker='o',
    )
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.grid(True)
    plt.legend(["Random", "Perturbed", "Sorted", "Reverse"]) 
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    plt.show()
    return fig, ax

# %%
array_size = 268435456
for name in function_names:
    plot_mpl(
        df=[ctk_random.dataframe.loc[name][array_size]["Avg time/rank"], 
            ctk_perturbed.dataframe.loc[name][array_size]["Avg time/rank"],
            ctk_sorted.dataframe.loc[name][array_size]["Avg time/rank"],
            ctk_reverse.dataframe.loc[name][array_size]["Avg time/rank"]],
        title="MPI Merge Sort {} Time for Array Size {}".format(name, array_size),
        xlabel="Ranks",
        ylabel="Time (seconds)",
    )

# %% [markdown]
# # Speedup Plotting

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    
    ax.plot(
        df,
        marker='o',
    )
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    plt.grid(True)
    plt.legend(array_sizes) 
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(processes)
    plt.show()
    return fig, ax

# %%
speedup_df = ctk_reverse.dataframe.loc[(slice(None),2), :].reset_index().drop("num_procs", axis=1).set_index('name')/ctk_random.dataframe
for name in function_names:
    plot_mpl(
        df=speedup_df.loc[name],
        title=f"{name}: thread-2/thread-N(Reverse)",
        xlabel="num_procs",
        ylabel="Speedup",
    )

# %%
print(speedup_df)
# Out:
#                                 65536         262144        1048576    \
#                             Avg time/rank Avg time/rank Avg time/rank
# name              num_procs
# main              2              1.000000      1.000000      1.000000
#                   4              0.291032      0.590919      0.650020
#                   8              0.195854      0.338458      0.397857
#                   16             0.114994      0.152114      0.197315
#                   32             0.046255      0.081266      0.089937
#                   64             0.032591      0.053109      0.062141
#                   128            0.030453      0.047578      0.060406
#                   256            0.029808      0.047169      0.051939
#                   512            0.026721      0.044027      0.055646
#                   1024           0.011510      0.018872      0.024377
# comm              2              1.000000      1.000000      1.000000
# ...

# %%
ctk_random.dataframe
# Out:
#                                 65536         262144        1048576    \
#                             Avg time/rank Avg time/rank Avg time/rank
# name              num_procs
# main              2              0.324260      0.524481      0.742772
#                   4              1.114173      0.887569      1.142691
#                   8              1.655617      1.549619      1.866930
#                   16             2.819803      3.447953      3.764403
#                   32             7.010326      6.453896      8.258817
#                   64             9.949373      9.875482     11.952923
#                   128           10.648010     11.023622     12.296301
#                   256           10.878121     11.119241     14.300875
#                   512           12.134988     11.912804     13.348261
#                   1024          28.172322     27.791735     30.470041
# comm              2              0.018591      0.056263      0.070128
# ...

# %%
ctk_random.dataframe.loc[(slice(None),2), :].reset_index().drop("num_procs", axis=1).set_index('name')
# Out:
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                       65536         262144        1048576       4194304    \
#                   Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# name
# main                   0.324260      0.524481      0.742772      1.565465
# comm                   0.018591      0.056263      0.070128      0.139827
# comm_large             0.018569      0.056244      0.070107      0.139804
# MPI_Barrier            0.013384      0.044950      0.059323      0.107037
# MPI_Gather             0.001865      0.010664      0.008560      0.011198
# MPI_Scatter            0.003266      0.000571      0.002154      0.021487
# comp                   0.012875      0.088909      0.407786      1.752726
# ...

# %%
ctk_random.dataframe.loc[(slice(None),8), :].reset_index().drop("num_procs", axis=1).set_index('name')
# Out:
# /sw/eb/sw/Anaconda3/2021.05/lib/python3.8/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                       65536         262144        1048576       4194304    \
#                   Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# name
# main                   1.655617      1.549619      1.866930      3.207777
# comm                   0.200017      0.175936      0.307985      0.870568
# comm_large             0.199994      0.175913      0.307962      0.870540
# MPI_Barrier            0.178007      0.171433      0.295171      0.824336
# MPI_Gather             0.020820      0.004199      0.003661      0.009659
# MPI_Scatter            0.001095      0.000223      0.009064      0.036453
# comp                   0.069529      0.383072      1.652224      7.052054
# ...
